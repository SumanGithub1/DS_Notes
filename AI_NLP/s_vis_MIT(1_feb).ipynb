# %% [markdown]
# #Visualisation

# %%
#Graphs you did before
#bar
#line
#scatter
#hist
#box
#heatmap
#pie
#count
#violin
#pairplot
#area/#dist
#doughnut

# %% [markdown]
# <h1 style="text-align:center;background-color:orange;padding:10px;">Data Visualization using Matplotlib</h1>
# <b>Matplotlib is a Python plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across multiple platforms.</b>
#
# <b><code>Matplotlib tries to make easy things easy and hard things possible.</code> You can generate plots, histograms, power spectra, bar charts, errorcharts, scatterplots, etc., with just a few lines of code.</b>
#
# The matplotlib library contains several modules. For example, the `matplotlib.table` module includes tools for constructing tables, the `matplotlib.text` module for including text in a figure, and the `matplotlib.colorbar` module allows you to visualize a set of scalar values in color. The `matplotlib.pyplot` module is designed to create colorful plots.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
print(matplotlib.__version__)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.2.2
# 1.3.5
# 1.21.6

# %%
fig, ax = plt.subplots()
x = np.linspace(0,10,300)
y = np.sin(x)+x

ax.plot(x,y)
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.03344482,  0.06688963,  0.10033445,  0.13377926,
#         0.16722408,  0.2006689 ,  0.23411371,  0.26755853,  0.30100334,
#         0.33444816,  0.36789298,  0.40133779,  0.43478261,  0.46822742,
#         0.50167224,  0.53511706,  0.56856187,  0.60200669,  0.63545151,
#         0.66889632,  0.70234114,  0.73578595,  0.76923077,  0.80267559,
#         0.8361204 ,  0.86956522,  0.90301003,  0.93645485,  0.96989967,
#         1.00334448,  1.0367893 ,  1.07023411,  1.10367893,  1.13712375,
#         1.17056856,  1.20401338,  1.23745819,  1.27090301,  1.30434783,
#         1.33779264,  1.37123746,  1.40468227,  1.43812709,  1.47157191,
#         1.50501672,  1.53846154,  1.57190635,  1.60535117,  1.63879599,
#         1.6722408 ,  1.70568562,  1.73913043,  1.77257525,  1.80602007,
#         1.83946488,  1.8729097 ,  1.90635452,  1.93979933,  1.97324415,
#         2.00668896,  2.04013378,  2.0735786 ,  2.10702341,  2.14046823,
# ...

# %%
fig, ax = plt.subplots(figsize = (10,5))
fig.suptitle("Our first plot", fontsize = 40)
ax.plot(x,y,c = 'r', linestyle = 'dashed', linewidth = 4)

# %%
fig, ax = plt.subplots(figsize = (10,5))
fig.suptitle("Our first plot", fontsize = 40)
ax.plot(x,y,c = 'r', linestyle = 'dashed', linewidth = 4)
ax.set_ylabel("function", fontsize = 20)
ax.set_xlabel("argument", fontsize = 20)

#ax.set_xlim(1, 20)  # this code is to change scale of your data
#ax.set_ylim(1, 20)

plt.tick_params(axis='both',labelsize=50)

# for xtick in ax.xaxis.get_major_ticks():
#     xtick.label.set_fontsize(50)

# for ytick in ax.yaxis.get_major_ticks():
#     ytick.label.set_fontsize(10)

# %%
fig, axes = plt.subplots(1, 3, figsize=(10,6))
ax1, ax2, ax3 = axes
x = np.linspace(0,10,500)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

ax1.set_ylabel('sin(x)', fontsize=30)
ax1.set_xlabel('x', fontsize=30)

ax2.set_ylabel('cos(x)', fontsize=30)
ax2.set_xlabel('x', fontsize=30)

ax3.set_ylabel('tan(x)', fontsize=30)
ax3.set_xlabel('x', fontsize=30)
fig.tight_layout(pad=2)

ax1.plot(x, y1, c='r', linewidth=4)
ax2.plot(x, y2, c='g', linewidth=4)
ax3.plot(x, y3, c='b', linewidth=4)
plt.show()

# %%
years=[1950,1955,1960,1965,1970,1980,1985,1990,1995,2000,2005,2010,2015]
pops=[2.5,2.7,3.0,3.3,3.6,4.0,4.4,4.8,5.3,5.7,6.1,6.5,7.3]

plt.plot(years,pops,color=(255/255,100/255,100/255))  #RGB tuple
plt.ylabel("Population in Billions")
plt.xlabel("Population growth by year")
plt.title("Population Growth")
# Out:
# Text(0.5, 1.0, 'Population Growth')

# %% [markdown]
# #LEGENDS, TITLES, LABELS

# %%
x = [1,6,3]
y = [5,9,4]

x2 = [1,2,3]
y2 = [10,14,12]

plt.plot(x, y, label='First Line')

plt.plot(x2, y2, label='Second Line')

plt.xlabel('Plot Number')
plt.ylabel('Important var')

plt.title('Interesting Graph Check it out')

plt.legend()
plt.show()

# %%
years=[1950,1955,1960,1965,1970,1980,1985,1990,1995,2000,2005,2010,2015]
pops=[2.5,2.7,3.0,3.3,3.6,4.0,4.4,4.8,5.3,5.7,6.1,6.5,7.3]
death=[1.2,1.1,1.2,2.1,2.0,2.3,1.8,1.9,2.6,1.6,2.4,2.4,4.0]

plt.plot(years,pops,'--',color=(255/255,100/255,100/255), marker = '*')

plt.plot(years,death,color=(.6,.6,1))

plt.grid(True)

plt.ylabel("Population in Billions")
plt.xlabel("Population growth by year")
plt.title("Population Growth")

for i, xy in enumerate([(0, 0), (1, 1), (2, 2), (3, 3)]):
    ax.annotate(f'({xy[0]}, {xy[1]})', xy=xy, xycoords='data',
                xytext=(-50, 30), textcoords='offset points',
                arrowprops=dict(arrowstyle="->",
                                connectionstyle="arc3,rad=.2"))

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot([0, 1, 2, 3], [0, 1, 2, 3], color=(0, 0.5, 0), marker='o', label='Line 1')
ax.plot([0, 1, 2, 3], [3, 2, 1, 0], color=(0.5, 0, 0.5), marker='^', label='Line 2')
ax.plot([0, 1, 2, 3], [0, 2, 1, 3], color=(0, 0.5, 1), marker='s', label='Line 3')

for i, xy in enumerate([(0, 0), (1, 1), (2, 2), (3, 3)]):
    ax.annotate(f'({xy[0]}, {xy[1]})', xy=xy, xycoords='data',
                xytext=(-50, 30), textcoords='offset points',
                arrowprops=dict(arrowstyle="->",
                                connectionstyle="arc3,rad=.2"))

ax.set_title('My Line Plot')

ax.set_xlabel('X Axis (units)')
ax.set_ylabel('Y Axis (units)')

ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# #PIE PLOT

# %%
data=[33,52,12,17,42,48]
plt.pie(data)
plt.show()

# %%
#Adding labels
labels=['Python','C','C++','PHP','Java','Ruby']
plt.pie(data,labels=['Python','C','C++','PHP','Java','Ruby'])
plt.show()

# %%
#Title and legend

plt.figure(figsize=(9, 7))
plt.pie(data,labels = labels)
plt.title('The results of the programming language survey', fontsize=14)
plt.legend(labels)
plt.show()

# %%
#Change them into slices  ---  explode

explode = [0.0, 0.8, 0.08, 0.08,0.08,0.0]
plt.pie(data, explode=explode, labels=labels)
plt.show()

# %%
#Shadows and colors

colors = ['saddlebrown', 'wheat', 'crimson', 'lightgrey','lightblue','darkblue']
plt.pie(data, 
        explode=explode, 
        labels=labels,
        autopct='%.2f%%',    # here we also add the % sign  
        colors=colors, 
        shadow=True)
plt.show()

# %%
#Insert doughtnut

colors = ['saddlebrown', 'wheat', 'crimson', 'lightgrey','lightblue','darkblue']
plt.pie(data, 
        explode=explode, 
        labels=labels,
        autopct='%.2f%%',    # here we also add the % sign  
        colors=colors,
        wedgeprops = {'width' : 0.4}, 
        shadow=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
width = 0.3

p_pie = ax.pie(data,radius=1,labels=labels, colors=colors,wedgeprops = {'width': width})

pets_data = [45, 41, 10, 4]
pets_labels = ['Apple', 'Carrot', 'Banana', 'Other']
pets_colors = ['orange', 'teal', 'powderblue', 'green']

pets_pie = ax.pie(pets_data, 
                  radius=1-width, 
                  labels=pets_labels,
                  labeldistance=0.7, 
                  colors=pets_colors, 
                  wedgeprops = {'width': width})

# %% [markdown]
# #BAR plot

# %%
films = ['Tanhaji', 'Baaghi 3', 'Love Aaj Kal', 'Jawaani Jaaneman', 'Street Dancer 3D']    
box_office = [367.65, 137.05, 44.77, 52.63, 97] 
plt.bar(films, box_office)        
plt.show()

# %%
#Grid lines

plt.bar(films, box_office)

# add grid lines
plt.grid(color='green', linestyle=':', linewidth=1.0, axis='x', alpha=0.5)

plt.ylabel('Box Office (crore . ₹)')  # labling y-axis
plt.xlabel('Film title')           # labling x-axis
plt.title('Box office of 5 different films of 2020 in the India')

plt.show()

# %%
plt.bar([1,3,5,7,9],[5,2,7,8,2], label="Example one")
plt.bar([2,4,6,8,10],[8,6,2,5,6], label="Example two", color='g')
plt.legend()
plt.xlabel('bar number')
plt.ylabel('bar height')

plt.title('Epic Graph\nAnother Line! Whoa')

plt.show()

# %%
# plotting the chart horizontally
plt.barh(films, box_office)

plt.xlabel('Box Office (crore . ₹)')
plt.ylabel('Film title')
plt.title('Box office of 5 different films of 2020 in the India')

plt.show()

# %%
korea_scores=(554,536,538)
canada_scores=(518,523,525)
china_scores=(413,570,580)
franch_scores=(495,505,499)

index=np.arange(3)
bar_width=.1

plt.figure(figsize=(10, 6))
k1=plt.bar(index,korea_scores,bar_width,alpha=0.1,label="Korea")
c1=plt.bar(index+bar_width,canada_scores,bar_width,alpha=.9,label="Canada")
ch1=plt.bar(index+bar_width*2,china_scores,bar_width,alpha=.9,label="China")
f1=plt.bar(index+bar_width*3,franch_scores,bar_width,alpha=.9,label="Franch")

plt.xticks(index+.6/2,('Mathematics','Reading','Science'))
plt.xticks(rotation = 45)
plt.ylabel('Mean score in PISA in 2012',fontsize=14)
plt.xlabel('Subjects',fontsize=14)
plt.title('Test scores by Country',fontsize=20)
plt.grid(True)
plt.legend()
plt.show()

# %%
years = ['2016', '2017', '2018', '2019']
rice = [57, 50, 47, 30]
wheat = [43, 50, 53, 70]

plt.figure(figsize=(10, 6))

plt.bar(years, rice, label='Rice')
plt.bar(years, wheat, bottom=rice, label='Wheat')

plt.xlabel('Years', fontsize=14)
plt.ylabel('Preference (%)', fontsize=14)
plt.title('The results of Rice/Wheat export', fontsize=20)
plt.legend()
plt.show()

# %%
years = ['2016', '2017', '2018', '2019']
rice =  np.array([57, 50, 47, 30])
wheat =  np.array([43, 50, 53, 70])
mustard =  np.array([10, 16, 13, 15])

plt.figure(figsize=(10, 6))
 
plt.bar(years, rice, label='Rice')
plt.bar(years, wheat, bottom=rice, label='Wheat')
plt.bar(years, mustard, bottom=rice+wheat, label='Mustard seeds')

plt.xlabel('Years', fontsize=14)
plt.ylabel('Preference (%)', fontsize=14)
plt.title('The results of Rice,Wheat & Mustard seeds export', fontsize=20)
plt.legend()
plt.show()
